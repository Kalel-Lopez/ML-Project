# %% [markdown]
# Machine Learning Project

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import pandas_datareader.data as pdr
import yfinance as yf
yf.pdr_override()

# %%
start = pd.to_datetime('2016-1-1')
end = pd.to_datetime('2020-1-1')

# %%
df = pdr.get_data_yahoo('WMT', start, end)  
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2016-01-04   60.500000   61.490002   60.360001   61.459999   52.916283
# 2016-01-05   62.029999   63.049999   61.849998   62.919998   54.173317
# 2016-01-06   62.480000   63.950001   62.470001   63.549999   54.715733
# 2016-01-07   62.970001   65.230003   62.919998   65.029999   55.989994
# 2016-01-08   65.080002   65.410004   63.410000   63.540001   54.707138
# ...                ...         ...         ...         ...         ...
# 2019-12-24  119.129997  119.599998  119.010002  119.510002  113.451996
# 2019-12-26  119.610001  119.849998  118.949997  119.519997  113.461479
# 2019-12-27  119.940002  119.940002  119.250000  119.589996  113.527924
# 2019-12-30  119.800003  119.809998  119.129997  119.400002  113.347572
# 2019-12-31  119.500000  119.800003  118.190002  118.839996  112.815948
#
#               Volume
# Date
# 2016-01-04  11989200
# 2016-01-05  13326000
# 2016-01-06  16564600
# 2016-01-07  26430000
# 2016-01-08  17767900
# ...              ...
# 2019-12-24   2227400
# 2019-12-26   4223800
# 2019-12-27   3544000
# 2019-12-30   2945800
# 2019-12-31   4912000
#
# [1006 rows x 6 columns]

# %%
top_plt = plt.subplot2grid((5,4), (0, 0), rowspan=3, colspan=4)
top_plt.plot(df.index, df["Close"])
plt.title('Walmart Stock Price [2016 to 2020]')
plt.gcf().set_size_inches(12,8)
plt.xlabel("Date")
plt.ylabel("Stock Price")
plt.show()
